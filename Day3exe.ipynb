# %% [markdown]
# <a href="https://colab.research.google.com/github/12-Teresa-py/Data-Science/blob/main/Day3exe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python workbook exercises

# %% [markdown]
# # Question 7(Sum of the first n positive integers)

# %%
n=int(input("Enter a positive integer"))
sum=((n*(n+1))/2)
print("the sum of positive integers is", sum)
# Out:
# Enter a positive integer 2
# the sum of positive integers is 3.0

# %% [markdown]
# # Question 8(Widgets and Gizmos)

# %%
w=int(input("Enter the number of widgets"))
w=(w*75)
g=int(input("Enter the number of gizmos"))
g=(g*112)
print("the total weight of order is", w+g)
# Out:
# Enter the number of widgets 2
# Enter the number of gizmos 2
# the total weight of order is 374

# %% [markdown]
# # Question 6(Tax and tip)
