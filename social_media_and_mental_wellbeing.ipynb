# %% [markdown]
# <a href="https://colab.research.google.com/github/12-Teresa-py/Data-Science/blob/main/social_media_and_mental_wellbeing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PANDAS (DAY 1)

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df = pd.read_csv("/content/social_media_addiction_mental_wellbeing.csv")
df.head()
# Out:
#     User_ID  Age      Gender            Occupation Relationship_Status  \
# 0  USR00001   30        Male  Working Professional   In a Relationship
# 1  USR00002   19        Male               Student             Married
# 2  USR00003   40        Male               Student   In a Relationship
# 3  USR00004   37      Female               Student             Married
# 4  USR00005   18  Non-binary               Student   In a Relationship
#
#   Primary_Platform  Daily_Usage_Hours  Platforms_Used_Count  Posts_Per_Week  \
# 0          YouTube                2.9                     4               3
# 1        Instagram                4.8                     1               0
# 2          YouTube                NaN                     4               5
# 3         Facebook                7.7                     2               3
# 4           TikTok                4.6                     3               0
#
#   Late_Night_Usage  ... Loneliness_Score  Self_Esteem_Score  \
# ...

# %%
df.tail()
# Out:
#        User_ID  Age      Gender            Occupation Relationship_Status  \
# 1495  USR01496   40        Male  Working Professional   In a Relationship
# 1496  USR01497   23  Non-binary               Student             Married
# 1497  USR01498   39      Female               Student              Single
# 1498  USR01499   26      Female            Freelancer              Single
# 1499  USR01500   16      Female  Working Professional   In a Relationship
#
#      Primary_Platform  Daily_Usage_Hours  Platforms_Used_Count  \
# 1495           TikTok                2.7                     2
# 1496          YouTube                3.5                     3
# 1497        Instagram                5.3                     2
# 1498        Twitter/X                7.3                     4
# 1499           TikTok                0.7                     3
#
#       Posts_Per_Week Late_Night_Usage  ... Loneliness_Score  \
# 1495               4               No  ...              3.3
# ...

# %%
df.head(10)
# Out:
#     User_ID  Age      Gender            Occupation Relationship_Status  \
# 0  USR00001   30        Male  Working Professional   In a Relationship
# 1  USR00002   19        Male               Student             Married
# 2  USR00003   40        Male               Student   In a Relationship
# 3  USR00004   37      Female               Student             Married
# 4  USR00005   18  Non-binary               Student   In a Relationship
# 5  USR00006   34        Male  Working Professional             Married
# 6  USR00007   38      Female               Student   In a Relationship
# 7  USR00008   22      Female            Unemployed              Single
# 8  USR00009   43      Female               Student              Single
# 9  USR00010   40        Male               Student              Single
#
#   Primary_Platform  Daily_Usage_Hours  Platforms_Used_Count  Posts_Per_Week  \
# 0          YouTube                2.9                     4               3
# ...

# %%
df.tail(12)
# Out:
#        User_ID  Age      Gender            Occupation Relationship_Status  \
# 1488  USR01489   22      Female               Student              Single
# 1489  USR01490   26      Female               Student             Married
# 1490  USR01491   31      Female               Student              Single
# 1491  USR01492   21  Non-binary               Student              Single
# 1492  USR01493   44        Male  Working Professional              Single
# 1493  USR01494   16        Male               Student              Single
# 1494  USR01495   27      Female               Student   In a Relationship
# 1495  USR01496   40        Male  Working Professional   In a Relationship
# 1496  USR01497   23  Non-binary               Student             Married
# 1497  USR01498   39      Female               Student              Single
# 1498  USR01499   26      Female            Freelancer              Single
# 1499  USR01500   16      Female  Working Professional   In a Relationship
#
# ...

# %%
df.shape
# Out:
# (1500, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   User_ID                       1500 non-null   object
#  1   Age                           1500 non-null   int64
#  2   Gender                        1447 non-null   object
#  3   Occupation                    1455 non-null   object
#  4   Relationship_Status           1449 non-null   object
#  5   Primary_Platform              1447 non-null   object
#  6   Daily_Usage_Hours             1444 non-null   float64
#  7   Platforms_Used_Count          1500 non-null   int64
#  8   Posts_Per_Week                1500 non-null   int64
#  9   Late_Night_Usage              1450 non-null   object
#  10  First_Check_Morning           1500 non-null   object
#  11  Notifications_Per_Day         1500 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  Daily_Usage_Hours  Platforms_Used_Count  Posts_Per_Week  \
# count  1500.000000        1444.000000           1500.000000     1500.000000
# mean     29.372000           4.521399              3.236000        3.936000
# std       8.550459           2.108319              1.682714        1.948273
# min      15.000000           0.500000              1.000000        0.000000
# 25%      22.000000           3.100000              2.000000        3.000000
# 50%      29.000000           4.400000              3.000000        4.000000
# 75%      37.000000           5.900000              4.000000        5.000000
# max      44.000000          12.000000              8.000000       12.000000
#
#        Notifications_Per_Day   FOMO_Score  Social_Comparison_Score  \
# count            1500.000000  1445.000000              1449.000000
# mean               60.244667     5.445882                 5.495514
# std                33.150688     2.183914                 2.041919
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Occupation', 'Relationship_Status',
#        'Primary_Platform', 'Daily_Usage_Hours', 'Platforms_Used_Count',
#        'Posts_Per_Week', 'Late_Night_Usage', 'First_Check_Morning',
#        'Notifications_Per_Day', 'FOMO_Score', 'Social_Comparison_Score',
#        'Validation_Seeking_Score', 'Scroll_Without_Purpose',
#        'Tried_To_Cut_Back', 'Failed_To_Cut_Back', 'Anxiety_Score',
#        'Depression_Score', 'Loneliness_Score', 'Self_Esteem_Score',
#        'Sleep_Quality_Score', 'Sleep_Hours', 'Productivity_Loss_Score',
#        'Offline_Relationship_Quality', 'Physical_Activity_Hrs_Week',
#        'Screen_Free_Time_Hrs', 'Mental_Wellbeing_Score', 'Addiction_Level'],
#       dtype='object')

# %%
df.dtypes
# Out:
# User_ID                          object
# Age                               int64
# Gender                           object
# Occupation                       object
# Relationship_Status              object
# Primary_Platform                 object
# Daily_Usage_Hours               float64
# Platforms_Used_Count              int64
# Posts_Per_Week                    int64
# Late_Night_Usage                 object
# First_Check_Morning              object
# Notifications_Per_Day             int64
# FOMO_Score                      float64
# Social_Comparison_Score         float64
# Validation_Seeking_Score        float64
# Scroll_Without_Purpose          float64
# Tried_To_Cut_Back                object
# Failed_To_Cut_Back               object
# Anxiety_Score                   float64
# Depression_Score                float64
# Loneliness_Score                float64
# Self_Esteem_Score               float64
# Sleep_Quality_Score             float64
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1500, step=1)

# %%
df.size
# Out:
# 45000

# %%
df["Age"].unique()
# Out:
# array([30, 19, 40, 37, 18, 34, 38, 22, 43, 29, 23, 25, 41, 21, 31, 27, 15,
#        26, 20, 39, 36, 42, 44, 17, 24, 16, 32, 33, 35, 28])

# %%
df["Age"].nunique()
# Out:
# 30

# %%
df["Age"]
# Out:
# 0       30
# 1       19
# 2       40
# 3       37
# 4       18
#         ..
# 1495    40
# 1496    23
# 1497    39
# 1498    26
# 1499    16
# Name: Age, Length: 1500, dtype: int64

# %%
df[["Age", "Gender"]]
# Out:
#       Age      Gender
# 0      30        Male
# 1      19        Male
# 2      40        Male
# 3      37      Female
# 4      18  Non-binary
# ...   ...         ...
# 1495   40        Male
# 1496   23  Non-binary
# 1497   39      Female
# 1498   26      Female
# 1499   16      Female
#
# [1500 rows x 2 columns]

# %%
df.loc[2, "Age"]
# Out:
# np.int64(40)

# %%
df.iloc[2,0]
# Out:
# 'USR00003'

# %%
df.loc[0]
# Out:
# User_ID                                     USR00001
# Age                                               30
# Gender                                          Male
# Occupation                      Working Professional
# Relationship_Status                In a Relationship
# Primary_Platform                             YouTube
# Daily_Usage_Hours                                2.9
# Platforms_Used_Count                               4
# Posts_Per_Week                                     3
# Late_Night_Usage                                  No
# First_Check_Morning                     Within 5 min
# Notifications_Per_Day                             62
# FOMO_Score                                       4.9
# Social_Comparison_Score                          7.4
# Validation_Seeking_Score                         2.1
# Scroll_Without_Purpose                          10.0
# Tried_To_Cut_Back                                 No
# Failed_To_Cut_Back                                No
# ...

# %%
df.iloc[0]
# Out:
# User_ID                                     USR00001
# Age                                               30
# Gender                                          Male
# Occupation                      Working Professional
# Relationship_Status                In a Relationship
# Primary_Platform                             YouTube
# Daily_Usage_Hours                                2.9
# Platforms_Used_Count                               4
# Posts_Per_Week                                     3
# Late_Night_Usage                                  No
# First_Check_Morning                     Within 5 min
# Notifications_Per_Day                             62
# FOMO_Score                                       4.9
# Social_Comparison_Score                          7.4
# Validation_Seeking_Score                         2.1
# Scroll_Without_Purpose                          10.0
# Tried_To_Cut_Back                                 No
# Failed_To_Cut_Back                                No
# ...

# %% [markdown]
# # PANDAS (DAY 2)
