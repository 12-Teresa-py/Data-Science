# %% [markdown]
# <a href="https://colab.research.google.com/github/12-Teresa-py/Data-Science/blob/main/Day6_morning_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 31( Sum of the digits in an integer)

# %%
four_dig_int = int(input("Enter a four digit integer:"))

sum = first_int + second_int + third_int + fourth_int
print(sum)
# Out:
# Enter a four digit integer:3141
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2181/2557284455.py in <cell line: 0>()
#       1 four_dig_int = int(input("Enter a four digit integer:"))
# ----> 2 sum = first_int + second_int + third_int + fourth_int
#       3 print(sum)
#
# NameError: name 'first_int' is not defined

# %%
height = float(input("Enter your height in meters:"))
weight = float(input("Enter your weight in kilograms:"))
BMI = weight/(height*height)
print(BMI)
# Out:
# Enter your height in meters:1.70
# Enter your weight in kilograms:70
# 24.221453287197235
