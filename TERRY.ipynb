# %% [markdown]
# <a href="https://colab.research.google.com/github/12-Teresa-py/Data-Science/blob/main/TERRY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction to Data Analytics (Python)

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(Hello World)
# Out:
#   File "/tmp/ipykernel_4751/4293340409.py", line 1
#     print(Hello World)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(10)
# Out:
# 10

# %%
Current_year=2026
Current_year=2025
Birth_year=2012
Age_1= Current_year-Birth_year
print(Age_1)
# Out:
# 13

# %%
print(2026-2012)
# Out:
# 14

# %%
name="Jane"
name="John"
print(name)
# Out:
# John

# %%
name= "John"
age= 20
print(name)
print(age)
# Out:
# John
# 20

# %%
print("My name  is Jane, I am 11 years old, my hobby is swimming")
# Out:
# My name  is Jane, I am 11 years old, my hobby is swimming

# %%
print("My name is Jane")
print ("I am 11 years old")
print ("My hobby is swimming")
# Out:
# My name is Jane
# I am 11 years old
# My hobby is swimming

# %%
name="John"
print("My name is", name)
# Out:
# My name is John

# %%
print(1,1)
# Out:
# 1 1

# %%
print("Hello","World")
# Out:
# Hello World

# %%
name= "Jane"
print(f"My name is {name}")
# Out:
# My name is Jane

# %%
print(f"My name is {name}")
# Out:
# My name is Jane
