# %% [markdown]
# <a href="https://colab.research.google.com/github/12-Teresa-py/Data-Science/blob/main/Day_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rgb_color = (101, 200, 25)
print(type(rgb_color))
print(rgb_color)
# Out:
# <class 'tuple'>
# (101, 200, 25)

# %%
pi_val = (3.14)
pi_tup = (3.14)
print(pi_val)
print(type(pi_tup))
# Out:
# 3.14
# <class 'float'>

# %%
names_tup = ("John","Mary","John","Peter")
print(names_tup.index("Mary"))
print(names_tup.count("John"))
# Out:
# 1
# 2

# %%
a,b = (10, 11)

# %%
print(b)
# Out:
# 11

# %%
for name in names_tup:
  print(name.upper())
# Out:
# JOHN
# MARY
# JOHN
# PETER

# %%
print([name.upper() for name in names_tup])
# Out:
# ['JOHN', 'MARY', 'JOHN', 'PETER']

# %%
fruits = ["apple", "mango", "apple", "mango", "banana"]
print(fruits)
# Out:
# ['apple', 'mango', 'apple', 'mango', 'banana']

# %%
fruits_set = {"apple", "mango", "apple", "mango", "banana"}
print(fruits_set)
# Out:
# {'banana', 'apple', 'mango'}

# %%
student_grades = {
    "math" :80,
    "english" :95,
    "cre" : 92
}
print(type(student_grades))
# Out:
# <class 'dict'>

# %%
math_results = student_grades["math"]
print(math_results)
# Out:
# 80

# %%
student_grades["math"] = 95
print(student_grades)
# Out:
# {'math': 95, 'english': 100}

# %%
del student_grades["cre"]

# %%
student_grades.update({"math":70, "english":100})

# %%
print(student_grades)
# Out:
# {'math': 95, 'english': 100}

# %%
for key in student_grades.keys():
  print(key.upper())
# Out:
# MATH
# ENGLISH

# %%
for val in student_grades.values():
  print(val)
# Out:
# 95
# 100

# %%
for item in student_grades.items():
  print(item)
# Out:
# ('math', 95)
# ('english', 100)

# %%
for key,val in student_grades.items():
  print(key, "", val)
