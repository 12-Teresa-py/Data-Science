# %% [markdown]
# <a href="https://colab.research.google.com/github/12-Teresa-py/Data-Science/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Input

# %%
name= input("What is your name")
# Out:
# What is your name  John

# %%
print(name)
# Out:
#   John

# %%
name=input("What is your name?")
print(f"Hello {name}!")
food=input("What is your favourite food?")
print(f"You like {food}")
sport=input('Whats your favourite sport? ')
print(f'Your favourite sport is {sport}')
# Out:
# What is your name?John
# Hello John!
# What is your favourite food?Fries
# You like Fries
# Whats your favourite sport? Football
# Your favourite sport is Football

# %%
age=input("Age:")
print(type(age))
# Out:
# Age:  10
# <class 'str'>

# %%
age= int(input("Age:"))
print(age)
print(type(age))
# Out:
# Age: 10
# 10
# <class 'int'>

# %%
a=9
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 12
# 6
# 27
# 3.0

# %%
fig_1=float(input("enter a value for fig_1:"))
print(fig_1)
fig_2=float(input("enter a value for fig_2"))
print(fig_2)
# Out:
# enter a value for fig_1:15
# 15.0
# enter a value for fig_23
# 3.0
# <class 'float'>

# %%
num_1=float(input("Enter the first value"))
num_2=float(input("Enter the second value"))
print("the sum of both values is", num_1+num_2)
print("the dif of both values is", num_1-num_2)
print("the prod of both values is", num_1*num_2)
print("the div of both values is", num_1/num_2)
print("the floor of both values is", num_1//num_2)
print("the remainder of both values is", num_1%num_2)
print("the power of both values is", num_1**num_2)
# Out:
# Enter the first value15
# Enter the second value3
# the sum of both values is 18.0
# the dif of both values is 12.0
# the prod of both values is 45.0
# the div of both values is 5.0
# the floor of both values is 5.0
# the remainder of both values is 0.0
# the power of both values is 3375.0

# %%
print(20>10)
# Out:
# True

# %%
print(20<10)
# Out:
# False

# %%
print(5==5)
# Out:
# True

# %%
print(5!=5)
# Out:
# False

# %%
name=input("Name:")
print=(type("Name:"))
age=input("Age:")
print=(type("Age years old"))
course=input("Course:")
print=(type("Course:"))
# Out:
# Name: Alice
# Age:20
# Course:Data Science 101

# %%
Item_name=input("Item_name")
print=(type("item_name"))
price=float(input("price:"))
print=(type("price:"))
quantity=int(input("quantity:"))
print=(type("quantity:"))
print=("the prod of both values is", price*quantity)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2476/1837793246.py in <cell line: 0>()
#       5 quantity=int(input("quantity:"))
#       6 print=(type("quantity:"))
# ----> 7 total=input("total:")
#       8 print=("the prod of both values is", price*quantity)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
length=float(input("length:"))
print(type("length"))
width=float(input("width:"))
print(type("width"))
area=length*width
print(f'Area: {area}')
# Out:
# length:99
# width:77
# 'Area: 7623.0'

# %% [markdown]
# # Area of a room

# %%
length=float(input("Enter the length of the room in feet:"))
width=float(input("Enter the width of the room in feet:"))
area=length*width
print("The area of the room is", area, "square feet")
# Out:
# Enter the length of the room in feet: 10
# Enter the width of the room in feet: 5
# The area of the room is 50.0 square feet
